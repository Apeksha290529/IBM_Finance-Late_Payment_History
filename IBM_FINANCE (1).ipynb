# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Data analytics  jason\pyton unuided project\WA_Fn-UseC_-Accounts-Receivable.csv")

# %%
df
# Out:
#       countryCode  customerID PaperlessDate  invoiceNumber InvoiceDate  \
# 0             391  0379-NEVHP      4/6/2013         611365    1/2/2013
# 1             406  8976-AMJEO      3/3/2012        7900770   1/26/2013
# 2             391  2820-XGXSB     1/26/2012        9231909    7/3/2013
# 3             406  9322-YCTQO      4/6/2012        9888306   2/10/2013
# 4             818  6627-ELFBK    11/26/2012       15752855  10/25/2012
# ...           ...         ...           ...            ...         ...
# 2461          391  6708-DPYTF      8/2/2012     9982796720  10/18/2013
# 2462          391  9841-XLGBV      1/3/2013     9983237240   9/19/2012
# 2463          770  7856-ODQFO      8/5/2012     9986249860    7/2/2012
# 2464          770  7050-KQLDO     9/29/2012     9989225541   4/27/2012
# 2465          406  9758-AIEIK     4/23/2012     9990243864    7/4/2013
#
#          DueDate  InvoiceAmount Disputed SettledDate PaperlessBill  \
# ...

# %%
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 2466 rows and 12 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2466 entries, 0 to 2465
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   countryCode    2466 non-null   int64
#  1   customerID     2466 non-null   object
#  2   PaperlessDate  2466 non-null   object
#  3   invoiceNumber  2466 non-null   int64
#  4   InvoiceDate    2466 non-null   object
#  5   DueDate        2466 non-null   object
#  6   InvoiceAmount  2466 non-null   float64
#  7   Disputed       2466 non-null   object
#  8   SettledDate    2466 non-null   object
#  9   PaperlessBill  2466 non-null   object
#  10  DaysToSettle   2466 non-null   int64
#  11  DaysLate       2466 non-null   int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 231.3+ KB

# %%
df.head()
# Out:
#    countryCode  customerID PaperlessDate  invoiceNumber InvoiceDate  \
# 0          391  0379-NEVHP      4/6/2013         611365    1/2/2013
# 1          406  8976-AMJEO      3/3/2012        7900770   1/26/2013
# 2          391  2820-XGXSB     1/26/2012        9231909    7/3/2013
# 3          406  9322-YCTQO      4/6/2012        9888306   2/10/2013
# 4          818  6627-ELFBK    11/26/2012       15752855  10/25/2012
#
#       DueDate  InvoiceAmount Disputed SettledDate PaperlessBill  DaysToSettle  \
# 0    2/1/2013          55.94       No   1/15/2013         Paper            13
# 1   2/25/2013          61.74      Yes    3/3/2013    Electronic            36
# 2    8/2/2013          65.88       No    7/8/2013    Electronic             5
# 3   3/12/2013         105.92       No   3/17/2013    Electronic            35
# 4  11/24/2012          72.27      Yes  11/28/2012         Paper            34
#
#    DaysLate
# 0         0
# 1         6
# 2         0
# 3         5
# 4         4

# %%
df.countryCode.value_counts()
# Out:
# countryCode
# 391    616
# 406    561
# 770    506
# 897    396
# 818    387
# Name: count, dtype: int64

# %%
cols_date = ["PaperlessDate","InvoiceDate","DueDate","SettledDate"]
for col in cols_date:
    df[col] = pd.to_datetime(df[col],format='%m/%d/%Y')
df.head()
# Out:
#    countryCode  customerID PaperlessDate  invoiceNumber InvoiceDate  \
# 0          391  0379-NEVHP    2013-04-06         611365  2013-01-02
# 1          406  8976-AMJEO    2012-03-03        7900770  2013-01-26
# 2          391  2820-XGXSB    2012-01-26        9231909  2013-07-03
# 3          406  9322-YCTQO    2012-04-06        9888306  2013-02-10
# 4          818  6627-ELFBK    2012-11-26       15752855  2012-10-25
#
#      DueDate  InvoiceAmount Disputed SettledDate PaperlessBill  DaysToSettle  \
# 0 2013-02-01          55.94       No  2013-01-15         Paper            13
# 1 2013-02-25          61.74      Yes  2013-03-03    Electronic            36
# 2 2013-08-02          65.88       No  2013-07-08    Electronic             5
# 3 2013-03-12         105.92       No  2013-03-17    Electronic            35
# 4 2012-11-24          72.27      Yes  2012-11-28         Paper            34
#
#    DaysLate
# 0         0
# 1         6
# 2         0
# 3         5
# 4         4

# %%
df.customerID.value_counts()
# Out:
# customerID
# 9149-MATVB    36
# 8887-NCUZC    35
# 4640-FGEJI    35
# 0688-XNJRO    34
# 9286-VLKMI    34
#               ..
# 4632-QZOKX    17
# 3676-CQAIF    17
# 7245-CKNCN    17
# 0187-ERLSR    16
# 2621-XCLEH    15
# Name: count, Length: 100, dtype: int64

# %%
temp = df.groupby(["countryCode"], axis=0, as_index=False)["customerID"].count()
sns.barplot(x='countryCode',y='customerID',data=temp,palette='bright')
plt.title('Customers per country')
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\678898319.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   temp = df.groupby(["countryCode"], axis=0, as_index=False)["customerID"].count()
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\678898319.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='countryCode',y='customerID',data=temp,palette='bright')
# Text(0.5, 1.0, 'Customers per country')

# %%
temp = df.groupby(["customerID"], axis=0, as_index=False)["InvoiceAmount"].mean().sort_values(by=['InvoiceAmount'],ascending=False)
temp.head(5)
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\3995171007.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   temp = df.groupby(["customerID"], axis=0, as_index=False)["InvoiceAmount"].mean().sort_values(by=['InvoiceAmount'],ascending=False)
#     customerID  InvoiceAmount
# 91  9322-YCTQO      87.959474
# 8   1080-NDGAE      85.380968
# 94  9725-EZTEJ      82.542308
# 46  5924-UOPGH      80.345172
# 41  5573-KSOIA      80.119583

# %%
plt.figure(figsize=(25,5))
sns.barplot(x='customerID',y='InvoiceAmount',data=temp,palette='bright')
plt.title('Average InvoiceAmount per Customer')
_ = plt.xticks(rotation=90,fontsize=14)
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\3967020168.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='customerID',y='InvoiceAmount',data=temp,palette='bright')

# %%
temp = df.groupby(["customerID"], axis=0, as_index=False)["DaysToSettle"].mean().sort_values(by=['DaysToSettle'],ascending=False)
temp.head(5)
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\184186513.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   temp = df.groupby(["customerID"], axis=0, as_index=False)["DaysToSettle"].mean().sort_values(by=['DaysToSettle'],ascending=False)
#     customerID  DaysToSettle
# 17  2621-XCLEH     49.533333
# 74  8102-ABPKQ     44.592593
# 4   0688-XNJRO     44.382353
# 12  1604-LIFKX     43.900000
# 43  5613-UHVMG     42.636364

# %%
plt.figure(figsize=(25,5))
sns.barplot(x='customerID',y='DaysToSettle',data=temp,palette='bright')
plt.title('Average DaysToSettle per Customer')
_ = plt.xticks(rotation=90,fontsize=14)
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\2942342443.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='customerID',y='DaysToSettle',data=temp,palette='bright')

# %%
temp = df.groupby(["customerID"], axis=0, as_index=False)["DaysLate"].mean().sort_values(by=['DaysLate'],ascending=False)
temp.head(5)
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\4239237179.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   temp = df.groupby(["customerID"], axis=0, as_index=False)["DaysLate"].mean().sort_values(by=['DaysLate'],ascending=False)
#     customerID   DaysLate
# 17  2621-XCLEH  19.600000
# 74  8102-ABPKQ  14.592593
# 4   0688-XNJRO  14.441176
# 12  1604-LIFKX  13.900000
# 43  5613-UHVMG  12.818182

# %%
temp.tail(20)
# Out:
#     customerID  DaysLate
# 48  6048-QPZCF  0.066667
# 49  6077-FDQRK  0.035714
# 81  8942-ERSWK  0.033333
# 79  8820-BLYDZ  0.000000
# 30  3993-QUNVJ  0.000000
# 18  2676-DZINU  0.000000
# 20  2820-XGXSB  0.000000
# 96  9771-QTLGZ  0.000000
# 22  3271-HYHDN  0.000000
# 27  3598-DNURW  0.000000
# 93  9460-VAZGD  0.000000
# 90  9286-VLKMI  0.000000
# 31  4092-ZAVRG  0.000000
# 47  6004-KITZM  0.000000
# 51  6177-VTITE  0.000000
# 52  6296-UKEUZ  0.000000
# 55  6632-CGYHU  0.000000
# 62  7245-CKNCN  0.000000
# 68  7695-NKUXM  0.000000
# 0   0187-ERLSR  0.000000

# %%
plt.figure(figsize=(25,5))
sns.barplot(x='customerID',y='DaysLate',data=temp,palette='bright')
plt.title('Average DaysLate per Customer')
_ = plt.xticks(rotation=90,fontsize=14)
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\1069086500.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='customerID',y='DaysLate',data=temp,palette='bright')

# %%
temp = df.groupby(["countryCode"], axis=0, as_index=False)[["InvoiceAmount","DaysToSettle","DaysLate"]].mean()
print('Average InvoiceAmount, DaysToSettle and DaysLate per country:')
temp.head(5)
# Out:
# Average InvoiceAmount, DaysToSettle and DaysLate per country:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\128063512.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   temp = df.groupby(["countryCode"], axis=0, as_index=False)[["InvoiceAmount","DaysToSettle","DaysLate"]].mean()
#    countryCode  InvoiceAmount  DaysToSettle  DaysLate
# 0          391      65.014545     23.448052  1.853896
# 1          406      70.272567     27.593583  3.941176
# 2          770      54.112194     28.160079  3.642292
# 3          818      63.312817     28.795866  4.816537
# 4          897      41.284040     24.989899  3.608586

# %%
temp = pd.DataFrame(df.groupby(['countryCode'], axis=0, as_index=False)['DaysLate'].mean())
plt.figure(figsize=(10,6))
sns.barplot(x="countryCode", y="DaysLate",data=temp,linewidth=2.5, facecolor=(1, 1, 1, 0),
                 errcolor=".4", edgecolor="red")
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\3621897229.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   temp = pd.DataFrame(df.groupby(['countryCode'], axis=0, as_index=False)['DaysLate'].mean())
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\3621897229.py:3: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '.4'}` instead.
#
#   sns.barplot(x="countryCode", y="DaysLate",data=temp,linewidth=2.5, facecolor=(1, 1, 1, 0),
# <Axes: xlabel='countryCode', ylabel='DaysLate'>

# %%
sns.displot(df, x="InvoiceAmount", hue="countryCode", element="step", palette='bright', height=8)
plt.title('InvoiceAmount distribution per country')
# Out:
# Text(0.5, 1.0, 'InvoiceAmount distribution per country')

# %%
sns.displot(df, x="DaysToSettle", hue="countryCode", element="step", palette='bright', height=8)
plt.title('DaysToSettle distribution per country')
# Out:
# Text(0.5, 1.0, 'DaysToSettle distribution per country')

# %%
sns.displot(df, x="DaysLate", hue="countryCode", element="step", palette='bright', height=8)
plt.title('DaysLate distribution per country')
# Out:
# Text(0.5, 1.0, 'DaysLate distribution per country')

# %%
sns.displot(df, x="DaysLate", hue="countryCode", element="step", palette='bright', height=8)
plt.title('DaysLate distribution per country (zoom)')
plt.ylim(0, 25)
# Out:
# (0.0, 25.0)

# %%
df[["InvoiceAmount","DaysToSettle","DaysLate"]].describe()
# Out:
#        InvoiceAmount  DaysToSettle     DaysLate
# count    2466.000000    2466.00000  2466.000000
# mean       59.895856      26.44485     3.442417
# std        20.435838      12.33493     6.290607
# min         5.260000       0.00000     0.000000
# 25%        46.400000      18.00000     0.000000
# 50%        60.560000      26.00000     0.000000
# 75%        73.765000      35.00000     5.000000
# max       128.280000      75.00000    45.000000

# %%
temp = df.groupby(["Disputed"], axis=0, as_index=False)["DaysLate"].mean().sort_values(by=['Disputed'],ascending=False)
sns.barplot(x='Disputed',y='DaysLate',data=temp,palette='bright')
plt.title('Average DaysLate')
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\1717965181.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   temp = df.groupby(["Disputed"], axis=0, as_index=False)["DaysLate"].mean().sort_values(by=['Disputed'],ascending=False)
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\1717965181.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Disputed',y='DaysLate',data=temp,palette='bright')
# Text(0.5, 1.0, 'Average DaysLate')

# %%
temp = df.groupby(["PaperlessBill"], axis=0, as_index=False)["DaysLate"].mean().sort_values(by=['PaperlessBill'],ascending=False)
sns.barplot(x='PaperlessBill',y='DaysLate',data=temp,palette='bright')
plt.title('Average DaysLate')
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\3956400506.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   temp = df.groupby(["PaperlessBill"], axis=0, as_index=False)["DaysLate"].mean().sort_values(by=['PaperlessBill'],ascending=False)
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\3956400506.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='PaperlessBill',y='DaysLate',data=temp,palette='bright')
# Text(0.5, 1.0, 'Average DaysLate')

# %%
df["InvoiceMonth"] = df["InvoiceDate"].dt.to_period('M')
df.head()
# Out:
#    countryCode  customerID PaperlessDate  invoiceNumber InvoiceDate  \
# 0          391  0379-NEVHP    2013-04-06         611365  2013-01-02
# 1          406  8976-AMJEO    2012-03-03        7900770  2013-01-26
# 2          391  2820-XGXSB    2012-01-26        9231909  2013-07-03
# 3          406  9322-YCTQO    2012-04-06        9888306  2013-02-10
# 4          818  6627-ELFBK    2012-11-26       15752855  2012-10-25
#
#      DueDate  InvoiceAmount Disputed SettledDate PaperlessBill  DaysToSettle  \
# 0 2013-02-01          55.94       No  2013-01-15         Paper            13
# 1 2013-02-25          61.74      Yes  2013-03-03    Electronic            36
# 2 2013-08-02          65.88       No  2013-07-08    Electronic             5
# 3 2013-03-12         105.92       No  2013-03-17    Electronic            35
# 4 2012-11-24          72.27      Yes  2012-11-28         Paper            34
#
#    DaysLate InvoiceMonth
# 0         0      2013-01
# 1         6      2013-01
# ...

# %%
temp = df.groupby(["InvoiceMonth"], axis=0, as_index=False)["invoiceNumber"].count()
sns.barplot(x='InvoiceMonth',y='invoiceNumber',data=temp,palette='bright')
plt.title('Invoices per month')
_ = plt.xticks(rotation=90,fontsize=14)
# Out:
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\742429132.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   temp = df.groupby(["InvoiceMonth"], axis=0, as_index=False)["invoiceNumber"].count()
# C:\Users\Apeksha ashok Bhoir\AppData\Local\Temp\ipykernel_10228\742429132.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='InvoiceMonth',y='invoiceNumber',data=temp,palette='bright')
